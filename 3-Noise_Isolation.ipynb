# %%
import numpy as np
import os
import librosa
import soundfile as sf

# %%
MIN_AUDIO_TIMESIZE = 5
SIZE_BY_SECOND = 32000

def segmentar(audio,y,sr):  # input an audio (y-array) to segment
    lista_segmentos=[]
    if len(y) > MIN_AUDIO_TIMESIZE * SIZE_BY_SECOND: # Minimum audio size 5 seconds
        print('Audio a segmentar----->',audio)
        for i in range(0, len(y)-int(MIN_AUDIO_TIMESIZE*SIZE_BY_SECOND),1*sr):
            segment = y[i:i+int(MIN_AUDIO_TIMESIZE*sr)]
            clip = segment.copy()
            lista_segmentos.append(clip)
    return lista_segmentos

# %%
def get_min_energy(L): # enter a list of segments (arrays) of a given audio
    energy_array= np.array([])
    for segment in L:
        rms_segment=np.sqrt(np.sum(segment**2)/len(segment))
        energy_array= np.append(energy_array,rms_segment)
    return np.min(energy_array),np.argmin(energy_array)

# %%
def proccess_sounds(relative_path):
    with open('features_min.csv', 'w') as csv_file:
        line=1
        csv_file.write("line,folder,sub_folder,audio,energy,index\n")
        for species in os.listdir(relative_path):
            for audio in os.listdir(relative_path+"/"+species):
                filename = relative_path+"/"+species+'/'+audio
                y, sr = librosa.load(filename, mono = True, sr=SIZE_BY_SECOND)
                y = y/np.max(np.abs(y))
                L=segmentar(audio,y,sr) 
                if L!=[]:  
                    min_energy,index = get_min_energy(L)
                    csv_file.write(str(line)+","+relative_path+","+species+","+audio+","+str(min_energy)+","+str(index)+"\n")
                    line=line+1
    print("Minima energia dos min filtrado",min_energy) # to take as a reference value as a minimum

# %%
def get_samples(count,seed):
    data = np.genfromtxt('features_min.csv', delimiter=',', dtype=None, names=True, encoding=None) 
    mean=np.mean(data['energy'])
    datos_filtrados = data[data['energy'] < mean]
    print("Dados Filtrados:",len(datos_filtrados))
    print("Mean:",mean)
    np.random.seed(seed)
    np.random.shuffle(datos_filtrados)

    samples = datos_filtrados[:count]

    return samples

# %%
def from_sample_to_wav(samples,output_root):
    if not os.path.exists(output_root):
        os.makedirs(output_root)
    for tupla in samples:
        path = tupla['folder']+"/"+tupla['sub_folder']+"/"+tupla['audio']

        y, sr = librosa.load(path, mono = True, sr=32000)
        y = y/np.max(np.abs(y))

        segment = y[tupla['index']*sr:(tupla['index']+MIN_AUDIO_TIMESIZE)*sr]
        
        new_path = output_root+"/silent_"+tupla['sub_folder']+"_"+tupla['audio']+".wav"
        new_path = new_path.replace(".ogg","")

        sf.write(new_path, segment, sr, subtype='PCM_24')

# %%
proccess_sounds("train_audio")
samples = get_samples(4000,42)
from_sample_to_wav(samples,"silence")
# Out:
# Audio a segmentar-----> XC793609.ogg
# Audio a segmentar-----> XC124420.ogg
# Audio a segmentar-----> XC636663.ogg
# Audio a segmentar-----> XC640480.ogg
# Audio a segmentar-----> XC615776.ogg
# Audio a segmentar-----> XC335666.ogg
# Audio a segmentar-----> XC138655.ogg
# Audio a segmentar-----> XC639943.ogg
# Audio a segmentar-----> XC635412.ogg
# Audio a segmentar-----> XC637334.ogg
# Audio a segmentar-----> XC637337.ogg
# Audio a segmentar-----> XC346561.ogg
# Audio a segmentar-----> XC448059.ogg
# Audio a segmentar-----> XC747554.ogg
# Audio a segmentar-----> XC213965.ogg
# Audio a segmentar-----> XC349693.ogg
# Audio a segmentar-----> XC615777.ogg
# Audio a segmentar-----> XC646710.ogg
# Audio a segmentar-----> XC509720.ogg
# Audio a segmentar-----> XC615774.ogg
# Audio a segmentar-----> XC19895.ogg
# Audio a segmentar-----> XC196950.ogg
# Audio a segmentar-----> XC164018.ogg
# Audio a segmentar-----> XC295481.ogg
# Audio a segmentar-----> XC209003.ogg
# Audio a segmentar-----> XC633433.ogg
# Audio a segmentar-----> XC575154.ogg
# Audio a segmentar-----> XC209004.ogg
# Audio a segmentar-----> XC481156.ogg
# Audio a segmentar-----> XC283657.ogg
# Audio a segmentar-----> XC209001.ogg
# Audio a segmentar-----> XC163926.ogg
# Audio a segmentar-----> XC342684.ogg
# Audio a segmentar-----> XC787331.ogg
# Audio a segmentar-----> XC469374.ogg
# Audio a segmentar-----> XC459286.ogg
# Audio a segmentar-----> XC163931.ogg
# Audio a segmentar-----> XC209556.ogg
# Audio a segmentar-----> XC276713.ogg
# Audio a segmentar-----> XC288097.ogg
# Audio a segmentar-----> XC208324.ogg
# Audio a segmentar-----> XC652567.ogg
# Audio a segmentar-----> XC741608.ogg
# Audio a segmentar-----> XC209565.ogg
# Audio a segmentar-----> XC285527.ogg
# Audio a segmentar-----> XC663208.ogg
# Audio a segmentar-----> XC209559.ogg
# Audio a segmentar-----> XC778578.ogg
# Audio a segmentar-----> XC633434.ogg
# Audio a segmentar-----> XC466299.ogg
# Audio a segmentar-----> XC209566.ogg
# Audio a segmentar-----> XC163925.ogg
# Audio a segmentar-----> XC320268.ogg
# Audio a segmentar-----> XC209005.ogg
# Audio a segmentar-----> XC575156.ogg
# Audio a segmentar-----> XC215849.ogg
# Audio a segmentar-----> XC207806.ogg
# Audio a segmentar-----> XC214025.ogg
# Audio a segmentar-----> XC163928.ogg
# Audio a segmentar-----> XC453725.ogg
# Audio a segmentar-----> XC452271.ogg
# Audio a segmentar-----> XC514065.ogg
# Audio a segmentar-----> XC163927.ogg
# Audio a segmentar-----> XC366608.ogg
# Audio a segmentar-----> XC197749.ogg
# Audio a segmentar-----> XC664544.ogg
# Audio a segmentar-----> XC476067.ogg
# Audio a segmentar-----> XC637085.ogg
# Audio a segmentar-----> XC381833.ogg
# Audio a segmentar-----> XC469552.ogg
# Audio a segmentar-----> XC557254.ogg
# Audio a segmentar-----> XC381329.ogg
# Audio a segmentar-----> XC668879.ogg
# Audio a segmentar-----> XC685750.ogg
# Audio a segmentar-----> XC573246.ogg
# Audio a segmentar-----> XC687197.ogg
# Audio a segmentar-----> XC278160.ogg
# Audio a segmentar-----> XC671350.ogg
# Audio a segmentar-----> XC652043.ogg
# Audio a segmentar-----> XC799978.ogg
# Audio a segmentar-----> XC343739.ogg
# Audio a segmentar-----> XC573248.ogg
# Audio a segmentar-----> XC497515.ogg
# Audio a segmentar-----> XC844041.ogg
# Audio a segmentar-----> XC544663.ogg
# Audio a segmentar-----> XC217918.ogg
# Audio a segmentar-----> XC642799.ogg
# Audio a segmentar-----> XC197615.ogg
# Audio a segmentar-----> XC381811.ogg
# Audio a segmentar-----> XC187383.ogg
# Audio a segmentar-----> XC347605.ogg
# Audio a segmentar-----> XC324627.ogg
# Audio a segmentar-----> XC471756.ogg
# Audio a segmentar-----> XC145349.ogg
# Audio a segmentar-----> XC190516.ogg
# Audio a segmentar-----> XC544803.ogg
# Audio a segmentar-----> XC717335.ogg
# Audio a segmentar-----> XC545316.ogg
# Audio a segmentar-----> XC746578.ogg
# Audio a segmentar-----> XC378704.ogg
# Audio a segmentar-----> XC795449.ogg
# Audio a segmentar-----> XC821352.ogg
# Audio a segmentar-----> XC821349.ogg
# Audio a segmentar-----> XC835012.ogg
# Audio a segmentar-----> XC585041.ogg
# Audio a segmentar-----> XC649226.ogg
# Audio a segmentar-----> XC266297.ogg
# Audio a segmentar-----> XC25907.ogg
# Audio a segmentar-----> XC754766.ogg
# Audio a segmentar-----> XC345156.ogg
# Audio a segmentar-----> XC378022.ogg
# Audio a segmentar-----> XC699303.ogg
# Audio a segmentar-----> XC746239.ogg
# Audio a segmentar-----> XC733183.ogg
# Audio a segmentar-----> XC814873.ogg
# Audio a segmentar-----> XC381827.ogg
# Audio a segmentar-----> XC635332.ogg
# Audio a segmentar-----> XC829050.ogg
# Audio a segmentar-----> XC488071.ogg
# Audio a segmentar-----> XC492565.ogg
# Audio a segmentar-----> XC747301.ogg
# Audio a segmentar-----> XC240476.ogg
# Audio a segmentar-----> XC647845.ogg
# Audio a segmentar-----> XC145348.ogg
# Audio a segmentar-----> XC478806.ogg
# Audio a segmentar-----> XC431019.ogg
# Audio a segmentar-----> XC496527.ogg
# Audio a segmentar-----> XC672707.ogg
# Audio a segmentar-----> XC583077.ogg
# Audio a segmentar-----> XC761927.ogg
# Audio a segmentar-----> XC841721.ogg
# Audio a segmentar-----> XC216813.ogg
# Audio a segmentar-----> XC580129.ogg
# Audio a segmentar-----> XC587085.ogg
# Audio a segmentar-----> XC381826.ogg
# Audio a segmentar-----> XC746240.ogg
# Audio a segmentar-----> XC381829.ogg
# Audio a segmentar-----> XC745724.ogg
# Audio a segmentar-----> XC659864.ogg
# Audio a segmentar-----> XC579396.ogg
# Audio a segmentar-----> XC265263.ogg
# Audio a segmentar-----> XC500554.ogg
# Audio a segmentar-----> XC770215.ogg
# Audio a segmentar-----> XC488069.ogg
# Audio a segmentar-----> XC827438.ogg
# Audio a segmentar-----> XC641451.ogg
# Audio a segmentar-----> XC647847.ogg
# Audio a segmentar-----> XC585184.ogg
# Audio a segmentar-----> XC375837.ogg
# Audio a segmentar-----> XC578229.ogg
# Audio a segmentar-----> XC821354.ogg
# Audio a segmentar-----> XC310519.ogg
# Audio a segmentar-----> XC768514.ogg
# Audio a segmentar-----> XC796552.ogg
# Audio a segmentar-----> XC648800.ogg
# Audio a segmentar-----> XC381824.ogg
# Audio a segmentar-----> XC664811.ogg
# Audio a segmentar-----> XC670441.ogg
# Audio a segmentar-----> XC551247.ogg
# Audio a segmentar-----> XC803143.ogg
# Audio a segmentar-----> XC557949.ogg
# Audio a segmentar-----> XC747319.ogg
# Audio a segmentar-----> XC216978.ogg
# Audio a segmentar-----> XC840776.ogg
# Audio a segmentar-----> XC372968.ogg
# Audio a segmentar-----> XC663081.ogg
# Audio a segmentar-----> XC401916.ogg
# Audio a segmentar-----> XC804790.ogg
# Audio a segmentar-----> XC263318.ogg
# Audio a segmentar-----> XC184454.ogg
# Audio a segmentar-----> XC584877.ogg
# Audio a segmentar-----> XC544863.ogg
# Audio a segmentar-----> XC488072.ogg
# Audio a segmentar-----> XC64713.ogg
# Audio a segmentar-----> XC808510.ogg
# Audio a segmentar-----> XC742132.ogg
# Audio a segmentar-----> XC805741.ogg
# Audio a segmentar-----> XC447001.ogg
# Audio a segmentar-----> XC110316.ogg
# Audio a segmentar-----> XC586200.ogg
# Audio a segmentar-----> XC447002.ogg
# Audio a segmentar-----> XC745588.ogg
# Audio a segmentar-----> XC687190.ogg
# Audio a segmentar-----> XC805739.ogg
# Audio a segmentar-----> XC309655.ogg
# Audio a segmentar-----> XC800972.ogg
# Audio a segmentar-----> XC666750.ogg
# Audio a segmentar-----> XC497658.ogg
# Audio a segmentar-----> XC492652.ogg
# Audio a segmentar-----> XC645926.ogg
# Audio a segmentar-----> XC827290.ogg
# Audio a segmentar-----> XC310586.ogg
# Audio a segmentar-----> XC822051.ogg
# Audio a segmentar-----> XC307284.ogg
# Audio a segmentar-----> XC668252.ogg
# Audio a segmentar-----> XC481808.ogg
# Audio a segmentar-----> XC664809.ogg
# Audio a segmentar-----> XC565576.ogg
# Audio a segmentar-----> XC840872.ogg
# Audio a segmentar-----> XC381238.ogg
# Audio a segmentar-----> XC556043.ogg
# Audio a segmentar-----> XC787834.ogg
# Audio a segmentar-----> XC344910.ogg
# Audio a segmentar-----> XC744040.ogg
# Audio a segmentar-----> XC305514.ogg
# Audio a segmentar-----> XC821351.ogg
# Audio a segmentar-----> XC551337.ogg
# Audio a segmentar-----> XC795922.ogg
# Audio a segmentar-----> XC743947.ogg
# Audio a segmentar-----> XC549750.ogg
# Audio a segmentar-----> XC754763.ogg
# Audio a segmentar-----> XC486250.ogg
# Audio a segmentar-----> XC423394.ogg
# Audio a segmentar-----> XC705355.ogg
# Audio a segmentar-----> XC144428.ogg
# Audio a segmentar-----> XC739348.ogg
# Audio a segmentar-----> XC580553.ogg
# Audio a segmentar-----> XC587077.ogg
# Audio a segmentar-----> XC567028.ogg
# Audio a segmentar-----> XC140651.ogg
# Audio a segmentar-----> XC25151.ogg
# Audio a segmentar-----> XC742926.ogg
# Audio a segmentar-----> XC282815.ogg
# Audio a segmentar-----> XC679589.ogg
# Audio a segmentar-----> XC573989.ogg
# Audio a segmentar-----> XC153897.ogg
# Audio a segmentar-----> XC743566.ogg
# Audio a segmentar-----> XC666087.ogg
# Audio a segmentar-----> XC796856.ogg
# Audio a segmentar-----> XC376849.ogg
# Audio a segmentar-----> XC646003.ogg
# Audio a segmentar-----> XC814695.ogg
# Audio a segmentar-----> XC647846.ogg
# Audio a segmentar-----> XC509675.ogg
# Audio a segmentar-----> XC494020.ogg
# Audio a segmentar-----> XC371015.ogg
# Audio a segmentar-----> XC724277.ogg
# Audio a segmentar-----> XC513494.ogg
# Audio a segmentar-----> XC663128.ogg
# Audio a segmentar-----> XC742928.ogg
# Audio a segmentar-----> XC740798.ogg
# Audio a segmentar-----> XC586201.ogg
# Audio a segmentar-----> XC585287.ogg
# Audio a segmentar-----> XC671941.ogg
# Audio a segmentar-----> XC240474.ogg
# Audio a segmentar-----> XC743639.ogg
# Audio a segmentar-----> XC814696.ogg
# Audio a segmentar-----> XC436740.ogg
# Audio a segmentar-----> XC644624.ogg
# Audio a segmentar-----> XC672983.ogg
# Audio a segmentar-----> XC559847.ogg
# Audio a segmentar-----> XC554677.ogg
# Audio a segmentar-----> XC25136.ogg
# Audio a segmentar-----> XC545085.ogg
# Audio a segmentar-----> XC363663.ogg
# Audio a segmentar-----> XC834767.ogg
# Audio a segmentar-----> XC579711.ogg
# Audio a segmentar-----> XC587076.ogg
# Audio a segmentar-----> XC825766.ogg
# Audio a segmentar-----> XC841458.ogg
# Audio a segmentar-----> XC820544.ogg
# Audio a segmentar-----> XC484263.ogg
# Audio a segmentar-----> XC493129.ogg
# Audio a segmentar-----> XC800004.ogg
# Audio a segmentar-----> XC754702.ogg
# Audio a segmentar-----> XC381812.ogg
# Audio a segmentar-----> XC145338.ogg
# Audio a segmentar-----> XC704756.ogg
# Audio a segmentar-----> XC738798.ogg
# Audio a segmentar-----> XC746580.ogg
# Audio a segmentar-----> XC554792.ogg
# Audio a segmentar-----> XC599390.ogg
# Audio a segmentar-----> XC581177.ogg
# Audio a segmentar-----> XC723451.ogg
# Audio a segmentar-----> XC644171.ogg
# Audio a segmentar-----> XC765769.ogg
# Audio a segmentar-----> XC335152.ogg
# Audio a segmentar-----> XC663903.ogg
# Audio a segmentar-----> XC342909.ogg
# Audio a segmentar-----> XC826962.ogg
# Audio a segmentar-----> XC380950.ogg
# Audio a segmentar-----> XC330350.ogg
# Audio a segmentar-----> XC589047.ogg
# Audio a segmentar-----> XC577273.ogg
# Audio a segmentar-----> XC204559.ogg
# Audio a segmentar-----> XC469043.ogg
# Audio a segmentar-----> XC146451.ogg
# Audio a segmentar-----> XC549757.ogg
# Audio a segmentar-----> XC509637.ogg
# Audio a segmentar-----> XC145327.ogg
# Audio a segmentar-----> XC374900.ogg
# Audio a segmentar-----> XC384800.ogg
# Audio a segmentar-----> XC840212.ogg
# Audio a segmentar-----> XC582100.ogg
# Audio a segmentar-----> XC658630.ogg
# Audio a segmentar-----> XC298161.ogg
# Audio a segmentar-----> XC432437.ogg
# Audio a segmentar-----> XC668548.ogg
# Audio a segmentar-----> XC747221.ogg
# Audio a segmentar-----> XC331100.ogg
# Audio a segmentar-----> XC530492.ogg
# Audio a segmentar-----> XC267072.ogg
# Audio a segmentar-----> XC787193.ogg
# Audio a segmentar-----> XC492304.ogg
# Audio a segmentar-----> XC666317.ogg
# Audio a segmentar-----> XC484264.ogg
# Audio a segmentar-----> XC490391.ogg
# Audio a segmentar-----> XC653281.ogg
# Audio a segmentar-----> XC724209.ogg
# Audio a segmentar-----> XC358470.ogg
# Audio a segmentar-----> XC494203.ogg
# Audio a segmentar-----> XC833723.ogg
# Audio a segmentar-----> XC505896.ogg
# Audio a segmentar-----> XC668264.ogg
# Audio a segmentar-----> XC821350.ogg
# Audio a segmentar-----> XC857970.ogg
# Audio a segmentar-----> XC827291.ogg
# Audio a segmentar-----> XC553364.ogg
# Audio a segmentar-----> XC265186.ogg
# Audio a segmentar-----> XC799418.ogg
# Audio a segmentar-----> XC669943.ogg
# Audio a segmentar-----> XC718689.ogg
# Audio a segmentar-----> XC428930.ogg
# Audio a segmentar-----> XC368106.ogg
# Audio a segmentar-----> XC672717.ogg
# Audio a segmentar-----> XC606815.ogg
# Audio a segmentar-----> XC666572.ogg
# Audio a segmentar-----> XC401915.ogg
# Audio a segmentar-----> XC25111.ogg
# Audio a segmentar-----> XC668256.ogg
# Audio a segmentar-----> XC601445.ogg
# Audio a segmentar-----> XC687200.ogg
# Audio a segmentar-----> XC821353.ogg
# Audio a segmentar-----> XC745768.ogg
# Audio a segmentar-----> XC746238.ogg
# Audio a segmentar-----> XC827125.ogg
# Audio a segmentar-----> XC664543.ogg
# Audio a segmentar-----> XC488070.ogg
# Audio a segmentar-----> XC728181.ogg
# Audio a segmentar-----> XC797773.ogg
# Audio a segmentar-----> XC184466.ogg
# Audio a segmentar-----> XC687191.ogg
# Audio a segmentar-----> XC663129.ogg
# Audio a segmentar-----> XC578599.ogg
# Audio a segmentar-----> XC820545.ogg
# Audio a segmentar-----> XC814623.ogg
# Audio a segmentar-----> XC804942.ogg
# Audio a segmentar-----> XC606814.ogg
# Audio a segmentar-----> XC696443.ogg
# Audio a segmentar-----> XC800998.ogg
# Audio a segmentar-----> XC702149.ogg
# Audio a segmentar-----> XC754173.ogg
# Audio a segmentar-----> XC559619.ogg
# Audio a segmentar-----> XC234697.ogg
# Audio a segmentar-----> XC672635.ogg
# Audio a segmentar-----> XC629318.ogg
# Audio a segmentar-----> XC741701.ogg
# Audio a segmentar-----> XC146063.ogg
# Audio a segmentar-----> XC282045.ogg
# Audio a segmentar-----> XC644599.ogg
# Audio a segmentar-----> XC740796.ogg
# Audio a segmentar-----> XC824740.ogg
# Audio a segmentar-----> XC696445.ogg
# Audio a segmentar-----> XC785539.ogg
# Audio a segmentar-----> XC800969.ogg
# Audio a segmentar-----> XC184464.ogg
# Audio a segmentar-----> XC715773.ogg
# Audio a segmentar-----> XC127465.ogg
# Audio a segmentar-----> XC131502.ogg
# Audio a segmentar-----> XC304114.ogg
# Audio a segmentar-----> XC670793.ogg
# Audio a segmentar-----> XC460591.ogg
# Audio a segmentar-----> XC184898.ogg
# Audio a segmentar-----> XC648200.ogg
# Audio a segmentar-----> XC187197.ogg
# Audio a segmentar-----> XC424655.ogg
# Audio a segmentar-----> XC735947.ogg
# Audio a segmentar-----> XC661721.ogg
# Audio a segmentar-----> XC201231.ogg
# Audio a segmentar-----> XC146617.ogg
# Audio a segmentar-----> XC380947.ogg
# Audio a segmentar-----> XC717013.ogg
# Audio a segmentar-----> XC825179.ogg
# Audio a segmentar-----> XC663490.ogg
# Audio a segmentar-----> XC363991.ogg
# Audio a segmentar-----> XC331279.ogg
# Audio a segmentar-----> XC833459.ogg
# Audio a segmentar-----> XC725070.ogg
# Audio a segmentar-----> XC733182.ogg
# Audio a segmentar-----> XC829104.ogg
# Audio a segmentar-----> XC380949.ogg
# Audio a segmentar-----> XC197600.ogg
# Audio a segmentar-----> XC506558.ogg
# Audio a segmentar-----> XC189355.ogg
# Audio a segmentar-----> XC730424.ogg
# Audio a segmentar-----> XC788053.ogg
# Audio a segmentar-----> XC642689.ogg
# Audio a segmentar-----> XC687192.ogg
# Audio a segmentar-----> XC184455.ogg
# Audio a segmentar-----> XC800595.ogg
# Audio a segmentar-----> XC643933.ogg
# Audio a segmentar-----> XC744448.ogg
# Audio a segmentar-----> XC821355.ogg
# Audio a segmentar-----> XC433124.ogg
# Audio a segmentar-----> XC827757.ogg
# Audio a segmentar-----> XC827432.ogg
# Audio a segmentar-----> XC530489.ogg
# Audio a segmentar-----> XC487833.ogg
# Audio a segmentar-----> XC718683.ogg
# Audio a segmentar-----> XC431212.ogg
# Audio a segmentar-----> XC266302.ogg
# Audio a segmentar-----> XC490140.ogg
# Audio a segmentar-----> XC804885.ogg
# Audio a segmentar-----> XC146456.ogg
# Audio a segmentar-----> XC64712.ogg
# Audio a segmentar-----> XC581779.ogg
# Audio a segmentar-----> XC825322.ogg
# Audio a segmentar-----> XC754765.ogg
# Audio a segmentar-----> XC749070.ogg
# Audio a segmentar-----> XC798524.ogg
# Audio a segmentar-----> XC742927.ogg
# Audio a segmentar-----> XC552623.ogg
# Audio a segmentar-----> XC526463.ogg
# Audio a segmentar-----> XC831152.ogg
# Audio a segmentar-----> XC672984.ogg
# Audio a segmentar-----> XC749410.ogg
# Audio a segmentar-----> XC744072.ogg
# Audio a segmentar-----> XC380293.ogg
# Audio a segmentar-----> XC687196.ogg
# Audio a segmentar-----> XC646008.ogg
# Audio a segmentar-----> XC799979.ogg
# Audio a segmentar-----> XC430928.ogg
# Audio a segmentar-----> XC471282.ogg
# Audio a segmentar-----> XC433536.ogg
# Audio a segmentar-----> XC821084.ogg
# Audio a segmentar-----> XC743640.ogg
# Audio a segmentar-----> XC856276.ogg
# Audio a segmentar-----> XC648533.ogg
# Audio a segmentar-----> XC146454.ogg
# Audio a segmentar-----> XC835157.ogg
# Audio a segmentar-----> XC187199.ogg
# Audio a segmentar-----> XC589100.ogg
# Audio a segmentar-----> XC793593.ogg
# Audio a segmentar-----> XC758292.ogg
# Audio a segmentar-----> XC823255.ogg
# Audio a segmentar-----> XC832210.ogg
# Audio a segmentar-----> XC738792.ogg
# Audio a segmentar-----> XC723788.ogg
# Audio a segmentar-----> XC668547.ogg
# Audio a segmentar-----> XC234695.ogg
# Audio a segmentar-----> XC827776.ogg
# Audio a segmentar-----> XC652326.ogg
# Audio a segmentar-----> XC841723.ogg
# Audio a segmentar-----> XC725188.ogg
# Audio a segmentar-----> XC184453.ogg
# Audio a segmentar-----> XC530490.ogg
# Audio a segmentar-----> XC549280.ogg
# Audio a segmentar-----> XC342908.ogg
# Audio a segmentar-----> XC190515.ogg
# Audio a segmentar-----> XC471902.ogg
# Audio a segmentar-----> XC638862.ogg
# Audio a segmentar-----> XC523429.ogg
# Audio a segmentar-----> XC827752.ogg
# Audio a segmentar-----> XC144919.ogg
# Audio a segmentar-----> XC668481.ogg
# Audio a segmentar-----> XC492223.ogg
# Audio a segmentar-----> XC663218.ogg
# Audio a segmentar-----> XC700153.ogg
# Audio a segmentar-----> XC431564.ogg
# Audio a segmentar-----> XC715781.ogg
# Audio a segmentar-----> XC471730.ogg
# Audio a segmentar-----> XC381832.ogg
# Audio a segmentar-----> XC816207.ogg
# Audio a segmentar-----> XC827124.ogg
# Audio a segmentar-----> XC187082.ogg
# Audio a segmentar-----> XC430418.ogg
# Audio a segmentar-----> XC799991.ogg
# Audio a segmentar-----> XC337590.ogg
# Audio a segmentar-----> XC424654.ogg
# Audio a segmentar-----> XC400539.ogg
# Audio a segmentar-----> XC530491.ogg
# Audio a segmentar-----> XC636797.ogg
# Audio a segmentar-----> XC555605.ogg
# Audio a segmentar-----> XC729119.ogg
# Audio a segmentar-----> XC586827.ogg
# Audio a segmentar-----> XC551341.ogg
# Audio a segmentar-----> XC584271.ogg
# Audio a segmentar-----> XC838633.ogg
# Audio a segmentar-----> XC747318.ogg
# Audio a segmentar-----> XC672720.ogg
# Audio a segmentar-----> XC555107.ogg
# Audio a segmentar-----> XC666052.ogg
# Audio a segmentar-----> XC717329.ogg
# Audio a segmentar-----> XC777455.ogg
# Audio a segmentar-----> XC645730.ogg
# Audio a segmentar-----> XC580128.ogg
# Audio a segmentar-----> XC431109.ogg
# Audio a segmentar-----> XC184460.ogg
# Audio a segmentar-----> XC664808.ogg
# Audio a segmentar-----> XC215036.ogg
# Audio a segmentar-----> XC381830.ogg
# Audio a segmentar-----> XC608282.ogg
# Audio a segmentar-----> XC792155.ogg
# Audio a segmentar-----> XC718690.ogg
# Audio a segmentar-----> XC664762.ogg
# Audio a segmentar-----> XC382304.ogg
# Audio a segmentar-----> XC557396.ogg
# Audio a segmentar-----> XC639767.ogg
# Audio a segmentar-----> XC724017.ogg
# Audio a segmentar-----> XC570750.ogg
# Audio a segmentar-----> XC469969.ogg
# Audio a segmentar-----> XC314265.ogg
# Audio a segmentar-----> XC190517.ogg
# Audio a segmentar-----> XC666101.ogg
# Audio a segmentar-----> XC824995.ogg
# Audio a segmentar-----> XC356504.ogg
# Audio a segmentar-----> XC785525.ogg
# Audio a segmentar-----> XC673257.ogg
# Audio a segmentar-----> XC641316.ogg
# Audio a segmentar-----> XC562056.ogg
# Audio a segmentar-----> XC808858.ogg
# Audio a segmentar-----> XC808144.ogg
# Audio a segmentar-----> XC830506.ogg
# Audio a segmentar-----> XC831886.ogg
# Audio a segmentar-----> XC346062.ogg
# Audio a segmentar-----> XC128179.ogg
# Audio a segmentar-----> XC577707.ogg
# Audio a segmentar-----> XC495039.ogg
# Audio a segmentar-----> XC737919.ogg
# Audio a segmentar-----> XC664545.ogg
# Audio a segmentar-----> XC801607.ogg
# Audio a segmentar-----> XC663130.ogg
# Audio a segmentar-----> XC788172.ogg
# Audio a segmentar-----> XC146902.ogg
# Audio a segmentar-----> XC643769.ogg
# Audio a segmentar-----> XC799366.ogg
# Audio a segmentar-----> XC565297.ogg
# Audio a segmentar-----> XC157571.ogg
# Audio a segmentar-----> XC689928.ogg
# Audio a segmentar-----> XC19922.ogg
# Audio a segmentar-----> XC740483.ogg
# Audio a segmentar-----> XC651968.ogg
# Audio a segmentar-----> XC64711.ogg
# Audio a segmentar-----> XC829103.ogg
# Audio a segmentar-----> XC690360.ogg
# Audio a segmentar-----> XC846041.ogg
# Audio a segmentar-----> XC662168.ogg
# Audio a segmentar-----> XC687198.ogg
# Audio a segmentar-----> XC387540.ogg
# Audio a segmentar-----> XC492495.ogg
# Audio a segmentar-----> XC182905.ogg
# Audio a segmentar-----> XC191239.ogg
# Audio a segmentar-----> XC829257.ogg
# Audio a segmentar-----> XC400538.ogg
# Audio a segmentar-----> XC476064.ogg
# Audio a segmentar-----> XC476671.ogg
# Audio a segmentar-----> XC140447.ogg
# Audio a segmentar-----> XC857968.ogg
# Audio a segmentar-----> XC669862.ogg
# Audio a segmentar-----> XC573243.ogg
# Audio a segmentar-----> XC265259.ogg
# Audio a segmentar-----> XC673073.ogg
# Audio a segmentar-----> XC814690.ogg
# Audio a segmentar-----> XC472029.ogg
# Audio a segmentar-----> XC113090.ogg
# Audio a segmentar-----> XC163857.ogg
# Audio a segmentar-----> XC787550.ogg
# Audio a segmentar-----> XC402455.ogg
# Audio a segmentar-----> XC116649.ogg
# Audio a segmentar-----> XC355973.ogg
# Audio a segmentar-----> XC199819.ogg
# Audio a segmentar-----> XC209192.ogg
# Audio a segmentar-----> XC826276.ogg
# Audio a segmentar-----> XC357593.ogg
# Audio a segmentar-----> XC430266.ogg
# Audio a segmentar-----> XC756303.ogg
# Audio a segmentar-----> XC163856.ogg
# Audio a segmentar-----> XC443745.ogg
# Audio a segmentar-----> XC208279.ogg
# Audio a segmentar-----> XC344137.ogg
# Audio a segmentar-----> XC634046.ogg
# Audio a segmentar-----> XC479822.ogg
# Audio a segmentar-----> XC662882.ogg
# Audio a segmentar-----> XC447036.ogg
# Audio a segmentar-----> XC39428.ogg
# Audio a segmentar-----> XC601411.ogg
# Audio a segmentar-----> XC687323.ogg
# Audio a segmentar-----> XC294462.ogg
# Audio a segmentar-----> XC777634.ogg
# Audio a segmentar-----> XC683047.ogg
# Audio a segmentar-----> XC604023.ogg
# Audio a segmentar-----> XC402081.ogg
# Audio a segmentar-----> XC209000.ogg
# Audio a segmentar-----> XC721596.ogg
# Audio a segmentar-----> XC625108.ogg
# Audio a segmentar-----> XC208676.ogg
# Audio a segmentar-----> XC686122.ogg
# Audio a segmentar-----> XC681127.ogg
# Audio a segmentar-----> XC116647.ogg
# Audio a segmentar-----> XC684879.ogg
# Audio a segmentar-----> XC179154.ogg
# Audio a segmentar-----> XC366729.ogg
# Audio a segmentar-----> XC677302.ogg
# Audio a segmentar-----> XC163860.ogg
# Audio a segmentar-----> XC163858.ogg
# Audio a segmentar-----> XC796825.ogg
# Audio a segmentar-----> XC601789.ogg
# Audio a segmentar-----> XC163854.ogg
# Audio a segmentar-----> XC443754.ogg
# Audio a segmentar-----> XC293565.ogg
# Audio a segmentar-----> XC438825.ogg
# Audio a segmentar-----> XC199820.ogg
# Audio a segmentar-----> XC208877.ogg
# Audio a segmentar-----> XC209018.ogg
# Audio a segmentar-----> XC626466.ogg
# Audio a segmentar-----> XC530998.ogg
# Audio a segmentar-----> XC293533.ogg
# Audio a segmentar-----> XC690877.ogg
# Audio a segmentar-----> XC392126.ogg
# Audio a segmentar-----> XC443067.ogg
# Audio a segmentar-----> XC443065.ogg
# Audio a segmentar-----> XC73378.ogg
# Audio a segmentar-----> XC446886.ogg
# Audio a segmentar-----> XC793460.ogg
# Audio a segmentar-----> XC681128.ogg
# Audio a segmentar-----> XC523319.ogg
# Audio a segmentar-----> XC454305.ogg
# Audio a segmentar-----> XC519656.ogg
# Audio a segmentar-----> XC835571.ogg
# Audio a segmentar-----> XC430265.ogg
# Audio a segmentar-----> XC443752.ogg
# Audio a segmentar-----> XC294461.ogg
# Audio a segmentar-----> XC42630.ogg
# Audio a segmentar-----> XC31544.ogg
# Audio a segmentar-----> XC736131.ogg
# Audio a segmentar-----> XC808314.ogg
# Audio a segmentar-----> XC601790.ogg
# Audio a segmentar-----> XC293534.ogg
# Audio a segmentar-----> XC194310.ogg
# Audio a segmentar-----> XC756610.ogg
# Audio a segmentar-----> XC667033.ogg
# Audio a segmentar-----> XC443742.ogg
# Audio a segmentar-----> XC531724.ogg
# Audio a segmentar-----> XC520666.ogg
# Audio a segmentar-----> XC626467.ogg
# Audio a segmentar-----> XC116648.ogg
# Audio a segmentar-----> XC443061.ogg
# Audio a segmentar-----> XC308330.ogg
# Audio a segmentar-----> XC733085.ogg
# Audio a segmentar-----> XC744704.ogg
# Audio a segmentar-----> XC735671.ogg
# Audio a segmentar-----> XC208879.ogg
# Audio a segmentar-----> XC163859.ogg
# Audio a segmentar-----> XC632057.ogg
# Audio a segmentar-----> XC779258.ogg
# Audio a segmentar-----> XC322403.ogg
# Audio a segmentar-----> XC198765.ogg
# Audio a segmentar-----> XC402083.ogg
# Audio a segmentar-----> XC209019.ogg
# Audio a segmentar-----> XC532303.ogg
# Audio a segmentar-----> XC596425.ogg
# Audio a segmentar-----> XC208579.ogg
# Audio a segmentar-----> XC608055.ogg
# Audio a segmentar-----> XC443062.ogg
# Audio a segmentar-----> XC197155.ogg
# Audio a segmentar-----> XC430824.ogg
# Audio a segmentar-----> XC146932.ogg
# Audio a segmentar-----> XC646963.ogg
# Audio a segmentar-----> XC255927.ogg
# Audio a segmentar-----> XC209201.ogg
# Audio a segmentar-----> XC191299.ogg
# Audio a segmentar-----> XC407853.ogg
# Audio a segmentar-----> XC403956.ogg
# Audio a segmentar-----> XC665874.ogg
# Audio a segmentar-----> XC552422.ogg
# Audio a segmentar-----> XC208278.ogg
# Audio a segmentar-----> XC163863.ogg
# Audio a segmentar-----> XC727677.ogg
# Audio a segmentar-----> XC743658.ogg
# Audio a segmentar-----> XC146952.ogg
# Audio a segmentar-----> XC163862.ogg
# Audio a segmentar-----> XC208684.ogg
# Audio a segmentar-----> XC163861.ogg
# Audio a segmentar-----> XC163864.ogg
# Audio a segmentar-----> XC778600.ogg
# Audio a segmentar-----> XC578839.ogg
# Audio a segmentar-----> XC443068.ogg
# Audio a segmentar-----> XC443063.ogg
# Audio a segmentar-----> XC443481.ogg
# Audio a segmentar-----> XC208875.ogg
# Audio a segmentar-----> XC164026.ogg
# Audio a segmentar-----> XC254340.ogg
# Audio a segmentar-----> XC595359.ogg
# Audio a segmentar-----> XC694105.ogg
# Audio a segmentar-----> XC197610.ogg
# Audio a segmentar-----> XC134748.ogg
# Audio a segmentar-----> XC342687.ogg
# Audio a segmentar-----> XC134733.ogg
# Audio a segmentar-----> XC168845.ogg
# Audio a segmentar-----> XC342686.ogg
# Audio a segmentar-----> XC178259.ogg
# Audio a segmentar-----> XC237600.ogg
# Audio a segmentar-----> XC779860.ogg
# Audio a segmentar-----> XC144762.ogg
# Audio a segmentar-----> XC405324.ogg
# Audio a segmentar-----> XC778595.ogg
# Audio a segmentar-----> XC619357.ogg
# Audio a segmentar-----> XC209511.ogg
# Audio a segmentar-----> XC337047.ogg
# Audio a segmentar-----> XC197827.ogg
# Audio a segmentar-----> XC611581.ogg
# Audio a segmentar-----> XC635699.ogg
# Audio a segmentar-----> XC444759.ogg
# Audio a segmentar-----> XC167566.ogg
# Audio a segmentar-----> XC469359.ogg
# Audio a segmentar-----> XC375728.ogg
# Audio a segmentar-----> XC395091.ogg
# Audio a segmentar-----> XC696226.ogg
# Audio a segmentar-----> XC37512.ogg
# Audio a segmentar-----> XC332453.ogg
# Audio a segmentar-----> XC696227.ogg
# Audio a segmentar-----> XC371176.ogg
# Audio a segmentar-----> XC447189.ogg
# Audio a segmentar-----> XC611583.ogg
# Audio a segmentar-----> XC351857.ogg
# Audio a segmentar-----> XC129278.ogg
# Audio a segmentar-----> XC308183.ogg
# Audio a segmentar-----> XC775466.ogg
# Audio a segmentar-----> XC405322.ogg
# Audio a segmentar-----> XC514845.ogg
# Audio a segmentar-----> XC691238.ogg
# Audio a segmentar-----> XC474849.ogg
# Audio a segmentar-----> XC667224.ogg
# Audio a segmentar-----> XC308571.ogg
# Audio a segmentar-----> XC667223.ogg
# Audio a segmentar-----> XC308191.ogg
# Audio a segmentar-----> XC73267.ogg
# Audio a segmentar-----> XC334051.ogg
# Audio a segmentar-----> XC404357.ogg
# Audio a segmentar-----> XC796874.ogg
# Audio a segmentar-----> XC779680.ogg
# Audio a segmentar-----> XC209510.ogg
# Audio a segmentar-----> XC639518.ogg
# Audio a segmentar-----> XC523562.ogg
# Audio a segmentar-----> XC73268.ogg
# Audio a segmentar-----> XC637788.ogg
# Audio a segmentar-----> XC459287.ogg
# Audio a segmentar-----> XC406118.ogg
# Audio a segmentar-----> XC459288.ogg
# Audio a segmentar-----> XC639517.ogg
# Audio a segmentar-----> XC441379.ogg
# Audio a segmentar-----> XC459199.ogg
# Audio a segmentar-----> XC371175.ogg
# Audio a segmentar-----> XC644011.ogg
# Audio a segmentar-----> XC761264.ogg
# Audio a segmentar-----> XC575193.ogg
# Audio a segmentar-----> XC151382.ogg
# Audio a segmentar-----> XC416452.ogg
# Audio a segmentar-----> XC824376.ogg
# Audio a segmentar-----> XC338700.ogg
# Audio a segmentar-----> XC784709.ogg
# Audio a segmentar-----> XC114849.ogg
# Audio a segmentar-----> XC359128.ogg
# Audio a segmentar-----> XC490594.ogg
# Audio a segmentar-----> XC575196.ogg
# Audio a segmentar-----> XC436744.ogg
# Audio a segmentar-----> XC637206.ogg
# Audio a segmentar-----> XC824375.ogg
# Audio a segmentar-----> XC824379.ogg
# Audio a segmentar-----> XC436746.ogg
# Audio a segmentar-----> XC494779.ogg
# Audio a segmentar-----> XC723722.ogg
# Audio a segmentar-----> XC209940.ogg
# Audio a segmentar-----> XC416849.ogg
# Audio a segmentar-----> XC196966.ogg
# Audio a segmentar-----> XC824377.ogg
# Audio a segmentar-----> XC637207.ogg
# Audio a segmentar-----> XC163479.ogg
# Audio a segmentar-----> XC409957.ogg
# Audio a segmentar-----> XC482241.ogg
# Audio a segmentar-----> XC742655.ogg
# Audio a segmentar-----> XC151383.ogg
# Audio a segmentar-----> XC715167.ogg
# Audio a segmentar-----> XC768348.ogg
# Audio a segmentar-----> XC330201.ogg
# Audio a segmentar-----> XC448878.ogg
# Audio a segmentar-----> XC114850.ogg
# Audio a segmentar-----> XC833711.ogg
# Audio a segmentar-----> XC196967.ogg
# Audio a segmentar-----> XC637211.ogg
# Audio a segmentar-----> XC614376.ogg
# Audio a segmentar-----> XC773231.ogg
# Audio a segmentar-----> XC575368.ogg
# Audio a segmentar-----> XC742656.ogg
# Audio a segmentar-----> XC355113.ogg
# Audio a segmentar-----> XC303559.ogg
# Audio a segmentar-----> XC348095.ogg
# Audio a segmentar-----> XC114847.ogg
# Audio a segmentar-----> XC607727.ogg
# Audio a segmentar-----> XC203823.ogg
# Audio a segmentar-----> XC824381.ogg
# Audio a segmentar-----> XC613168.ogg
# Audio a segmentar-----> XC438803.ogg
# Audio a segmentar-----> XC179449.ogg
# Audio a segmentar-----> XC755929.ogg
# Audio a segmentar-----> XC768401.ogg
# Audio a segmentar-----> XC114848.ogg
# Audio a segmentar-----> XC448877.ogg
# Audio a segmentar-----> XC531811.ogg
# Audio a segmentar-----> XC637201.ogg
# Audio a segmentar-----> XC637210.ogg
# Audio a segmentar-----> XC510520.ogg
# Audio a segmentar-----> XC303757.ogg
# Audio a segmentar-----> XC746561.ogg
# Audio a segmentar-----> XC269604.ogg
# Audio a segmentar-----> XC637203.ogg
# Audio a segmentar-----> XC633486.ogg
# Audio a segmentar-----> XC453714.ogg
# Audio a segmentar-----> XC824380.ogg
# Audio a segmentar-----> XC169532.ogg
# Audio a segmentar-----> XC355112.ogg
# Audio a segmentar-----> XC470445.ogg
# Audio a segmentar-----> XC355111.ogg
# Audio a segmentar-----> XC845574.ogg
# Audio a segmentar-----> XC511722.ogg
# Audio a segmentar-----> XC151078.ogg
# Audio a segmentar-----> XC856062.ogg
# Audio a segmentar-----> XC777297.ogg
# Audio a segmentar-----> XC390754.ogg
# Audio a segmentar-----> XC606845.ogg
# Audio a segmentar-----> XC244319.ogg
# Audio a segmentar-----> XC192481.ogg
# Audio a segmentar-----> XC653116.ogg
# Audio a segmentar-----> XC150857.ogg
# Audio a segmentar-----> XC722436.ogg
# Audio a segmentar-----> XC150830.ogg
# Audio a segmentar-----> XC178283.ogg
# Audio a segmentar-----> XC186547.ogg
# Audio a segmentar-----> XC785891.ogg
# Audio a segmentar-----> XC362684.ogg
# Audio a segmentar-----> XC653406.ogg
# Audio a segmentar-----> XC296645.ogg
# Audio a segmentar-----> XC177917.ogg
# Audio a segmentar-----> XC215861.ogg
# Audio a segmentar-----> XC296441.ogg
# Audio a segmentar-----> XC188890.ogg
# Audio a segmentar-----> XC279171.ogg
# Audio a segmentar-----> XC116771.ogg
# Audio a segmentar-----> XC459322.ogg
# Audio a segmentar-----> XC279169.ogg
# Audio a segmentar-----> XC229003.ogg
# Audio a segmentar-----> XC179567.ogg
# Audio a segmentar-----> XC192483.ogg
# Audio a segmentar-----> XC654426.ogg
# Audio a segmentar-----> XC505510.ogg
# Audio a segmentar-----> XC443912.ogg
# Audio a segmentar-----> XC267076.ogg
# Audio a segmentar-----> XC29580.ogg
# Audio a segmentar-----> XC307335.ogg
# Audio a segmentar-----> XC29579.ogg
# Audio a segmentar-----> XC342506.ogg
# Audio a segmentar-----> XC560839.ogg
# Audio a segmentar-----> XC708251.ogg
# Audio a segmentar-----> XC150862.ogg
# Audio a segmentar-----> XC126809.ogg
# Audio a segmentar-----> XC505509.ogg
# Audio a segmentar-----> XC701168.ogg
# Audio a segmentar-----> XC440795.ogg
# Audio a segmentar-----> XC535360.ogg
# Audio a segmentar-----> XC807854.ogg
# Audio a segmentar-----> XC840214.ogg
# Audio a segmentar-----> XC439701.ogg
# Audio a segmentar-----> XC722435.ogg
# Audio a segmentar-----> XC761904.ogg
# Audio a segmentar-----> XC610766.ogg
# Audio a segmentar-----> XC724788.ogg
# Audio a segmentar-----> XC29581.ogg
# Audio a segmentar-----> XC721636.ogg
# Audio a segmentar-----> XC57248.ogg
# Audio a segmentar-----> XC162999.ogg
# Audio a segmentar-----> XC292609.ogg
# Audio a segmentar-----> XC151211.ogg
# Audio a segmentar-----> XC639714.ogg
# Audio a segmentar-----> XC439699.ogg
# Audio a segmentar-----> XC390753.ogg
# Audio a segmentar-----> XC705583.ogg
# Audio a segmentar-----> XC150859.ogg
# Audio a segmentar-----> XC413781.ogg
# Audio a segmentar-----> XC57249.ogg
# Audio a segmentar-----> XC730887.ogg
# Audio a segmentar-----> XC216927.ogg
# Audio a segmentar-----> XC578945.ogg
# Audio a segmentar-----> XC319390.ogg
# Audio a segmentar-----> XC184819.ogg
# Audio a segmentar-----> XC619549.ogg
# Audio a segmentar-----> XC708249.ogg
# Audio a segmentar-----> XC283502.ogg
# Audio a segmentar-----> XC661272.ogg
# Audio a segmentar-----> XC653115.ogg
# Audio a segmentar-----> XC614428.ogg
# Audio a segmentar-----> XC398561.ogg
# Audio a segmentar-----> XC775132.ogg
# Audio a segmentar-----> XC287101.ogg
# Audio a segmentar-----> XC619541.ogg
# Audio a segmentar-----> XC578362.ogg
# Audio a segmentar-----> XC151077.ogg
# Audio a segmentar-----> XC511720.ogg
# Audio a segmentar-----> XC241960.ogg
# Audio a segmentar-----> XC402333.ogg
# Audio a segmentar-----> XC811558.ogg
# Audio a segmentar-----> XC683316.ogg
# Audio a segmentar-----> XC286720.ogg
# Audio a segmentar-----> XC721637.ogg
# Audio a segmentar-----> XC683302.ogg
# Audio a segmentar-----> XC631760.ogg
# Audio a segmentar-----> XC511719.ogg
# Audio a segmentar-----> XC197380.ogg
# Audio a segmentar-----> XC756452.ogg
# Audio a segmentar-----> XC679484.ogg
# Audio a segmentar-----> XC618632.ogg
# Audio a segmentar-----> XC126807.ogg
# Audio a segmentar-----> XC674522.ogg
# Audio a segmentar-----> XC241955.ogg
# Audio a segmentar-----> XC363423.ogg
# Audio a segmentar-----> XC404221.ogg
# Audio a segmentar-----> XC724462.ogg
# Audio a segmentar-----> XC151076.ogg
# Audio a segmentar-----> XC440796.ogg
# Audio a segmentar-----> XC126805.ogg
# Audio a segmentar-----> XC446977.ogg
# Audio a segmentar-----> XC402334.ogg
# Audio a segmentar-----> XC632290.ogg
# Audio a segmentar-----> XC407546.ogg
# Audio a segmentar-----> XC168288.ogg
# Audio a segmentar-----> XC279170.ogg
# Audio a segmentar-----> XC216928.ogg
# Audio a segmentar-----> XC321615.ogg
# Audio a segmentar-----> XC57648.ogg
# Audio a segmentar-----> XC653407.ogg
# Audio a segmentar-----> XC654686.ogg
# Audio a segmentar-----> XC423067.ogg
# Audio a segmentar-----> XC182157.ogg
# Audio a segmentar-----> XC681117.ogg
# Audio a segmentar-----> XC458520.ogg
# Audio a segmentar-----> XC485017.ogg
# Audio a segmentar-----> XC155668.ogg
# Audio a segmentar-----> XC755642.ogg
# Audio a segmentar-----> XC343307.ogg
# Audio a segmentar-----> XC805623.ogg
# Audio a segmentar-----> XC750433.ogg
# Audio a segmentar-----> XC485018.ogg
# Audio a segmentar-----> XC728672.ogg
# Audio a segmentar-----> XC612414.ogg
# Audio a segmentar-----> XC858115.ogg
# Audio a segmentar-----> XC482718.ogg
# Audio a segmentar-----> XC612193.ogg
# Audio a segmentar-----> XC768917.ogg
# Audio a segmentar-----> XC808528.ogg
# Audio a segmentar-----> XC720152.ogg
# Audio a segmentar-----> XC761422.ogg
# Audio a segmentar-----> XC164842.ogg
# Audio a segmentar-----> XC682049.ogg
# Audio a segmentar-----> XC857838.ogg
# Audio a segmentar-----> XC266177.ogg
# Audio a segmentar-----> XC117085.ogg
# Audio a segmentar-----> XC340013.ogg
# Audio a segmentar-----> XC340033.ogg
# Audio a segmentar-----> XC485863.ogg
# Audio a segmentar-----> XC485181.ogg
# Audio a segmentar-----> XC755637.ogg
# Audio a segmentar-----> XC484890.ogg
# Audio a segmentar-----> XC340011.ogg
# Audio a segmentar-----> XC519687.ogg
# Audio a segmentar-----> XC771151.ogg
# Audio a segmentar-----> XC527354.ogg
# Audio a segmentar-----> XC485178.ogg
# Audio a segmentar-----> XC141833.ogg
# Audio a segmentar-----> XC842818.ogg
# Audio a segmentar-----> XC859316.ogg
# Audio a segmentar-----> XC607433.ogg
# Audio a segmentar-----> XC859315.ogg
# Audio a segmentar-----> XC777628.ogg
# Audio a segmentar-----> XC755644.ogg
# Audio a segmentar-----> XC778803.ogg
# Audio a segmentar-----> XC373546.ogg
# Audio a segmentar-----> XC611356.ogg
# Audio a segmentar-----> XC683283.ogg
# Audio a segmentar-----> XC266176.ogg
# Audio a segmentar-----> XC266173.ogg
# Audio a segmentar-----> XC323743.ogg
# Audio a segmentar-----> XC842777.ogg
# Audio a segmentar-----> XC209934.ogg
# Audio a segmentar-----> XC841655.ogg
# Audio a segmentar-----> XC755640.ogg
# Audio a segmentar-----> XC485180.ogg
# Audio a segmentar-----> XC703757.ogg
# Audio a segmentar-----> XC667277.ogg
# Audio a segmentar-----> XC755636.ogg
# Audio a segmentar-----> XC777656.ogg
# Audio a segmentar-----> XC727519.ogg
# Audio a segmentar-----> XC824776.ogg
# Audio a segmentar-----> XC857839.ogg
# Audio a segmentar-----> XC777658.ogg
# Audio a segmentar-----> XC340012.ogg
# Audio a segmentar-----> XC439766.ogg
# Audio a segmentar-----> XC485182.ogg
# Audio a segmentar-----> XC352389.ogg
# Audio a segmentar-----> XC304072.ogg
# Audio a segmentar-----> XC478622.ogg
# Audio a segmentar-----> XC803371.ogg
# Audio a segmentar-----> XC607434.ogg
# Audio a segmentar-----> XC239436.ogg
# Audio a segmentar-----> XC542433.ogg
# Audio a segmentar-----> XC821759.ogg
# Audio a segmentar-----> XC840612.ogg
# Audio a segmentar-----> XC755643.ogg
# Audio a segmentar-----> XC527355.ogg
# Audio a segmentar-----> XC146026.ogg
# Audio a segmentar-----> XC298326.ogg
# Audio a segmentar-----> XC552310.ogg
# Audio a segmentar-----> XC394029.ogg
# Audio a segmentar-----> XC785360.ogg
# Audio a segmentar-----> XC329218.ogg
# Audio a segmentar-----> XC755639.ogg
# Audio a segmentar-----> XC458137.ogg
# Audio a segmentar-----> XC508626.ogg
# Audio a segmentar-----> XC117058.ogg
# Audio a segmentar-----> XC845334.ogg
# Audio a segmentar-----> XC667285.ogg
# Audio a segmentar-----> XC841654.ogg
# Audio a segmentar-----> XC700952.ogg
# Audio a segmentar-----> XC485177.ogg
# Audio a segmentar-----> XC604740.ogg
# Audio a segmentar-----> XC786973.ogg
# Audio a segmentar-----> XC777659.ogg
# Audio a segmentar-----> XC305513.ogg
# Audio a segmentar-----> XC485179.ogg
# Audio a segmentar-----> XC484123.ogg
# Audio a segmentar-----> XC117059.ogg
# Audio a segmentar-----> XC458521.ogg
# Audio a segmentar-----> XC375246.ogg
# Audio a segmentar-----> XC398811.ogg
# Audio a segmentar-----> XC700157.ogg
# Audio a segmentar-----> XC569673.ogg
# Audio a segmentar-----> XC699153.ogg
# Audio a segmentar-----> XC713215.ogg
# Audio a segmentar-----> XC576602.ogg
# Audio a segmentar-----> XC621031.ogg
# Audio a segmentar-----> XC509475.ogg
# Audio a segmentar-----> XC589194.ogg
# Audio a segmentar-----> XC602308.ogg
# Audio a segmentar-----> XC208575.ogg
# Audio a segmentar-----> XC405607.ogg
# Audio a segmentar-----> XC529864.ogg
# Audio a segmentar-----> XC621033.ogg
# Audio a segmentar-----> XC588707.ogg
# Audio a segmentar-----> XC118201.ogg
# Audio a segmentar-----> XC304003.ogg
# Audio a segmentar-----> XC338843.ogg
# Audio a segmentar-----> XC208589.ogg
# Audio a segmentar-----> XC700156.ogg
# Audio a segmentar-----> XC621034.ogg
# Audio a segmentar-----> XC304004.ogg
# Audio a segmentar-----> XC196955.ogg
# Audio a segmentar-----> XC208808.ogg
# Audio a segmentar-----> XC590326.ogg
# Audio a segmentar-----> XC453344.ogg
# Audio a segmentar-----> XC303999.ogg
# Audio a segmentar-----> XC699151.ogg
# Audio a segmentar-----> XC569674.ogg
# Audio a segmentar-----> XC584168.ogg
# Audio a segmentar-----> XC782106.ogg
# Audio a segmentar-----> XC461981.ogg
# Audio a segmentar-----> XC174979.ogg
# Audio a segmentar-----> XC291823.ogg
# Audio a segmentar-----> XC37509.ogg
# Audio a segmentar-----> XC699152.ogg
# Audio a segmentar-----> XC236712.ogg
# Audio a segmentar-----> XC621032.ogg
# Audio a segmentar-----> XC209930.ogg
# Audio a segmentar-----> XC408101.ogg
# Audio a segmentar-----> XC125592.ogg
# Audio a segmentar-----> XC197753.ogg
# Audio a segmentar-----> XC198617.ogg
# Audio a segmentar-----> XC118200.ogg
# Audio a segmentar-----> XC621030.ogg
# Audio a segmentar-----> XC276714.ogg
# Audio a segmentar-----> XC318464.ogg
# Audio a segmentar-----> XC359294.ogg
# Audio a segmentar-----> XC336767.ogg
# Audio a segmentar-----> XC699154.ogg
# Audio a segmentar-----> XC452273.ogg
# Audio a segmentar-----> XC437483.ogg
# Audio a segmentar-----> XC509474.ogg
# Audio a segmentar-----> XC208806.ogg
# Audio a segmentar-----> XC240335.ogg
# Audio a segmentar-----> XC390252.ogg
# Audio a segmentar-----> XC330925.ogg
# Audio a segmentar-----> XC196655.ogg
# Audio a segmentar-----> XC436340.ogg
# Audio a segmentar-----> XC463162.ogg
# Audio a segmentar-----> XC423902.ogg
# Audio a segmentar-----> XC796158.ogg
# Audio a segmentar-----> XC433098.ogg
# Audio a segmentar-----> XC701892.ogg
# Audio a segmentar-----> XC390259.ogg
# Audio a segmentar-----> XC436339.ogg
# Audio a segmentar-----> XC423973.ogg
# Audio a segmentar-----> XC278139.ogg
# Audio a segmentar-----> XC701890.ogg
# Audio a segmentar-----> XC207025.ogg
# Audio a segmentar-----> XC390262.ogg
# Audio a segmentar-----> XC390255.ogg
# Audio a segmentar-----> XC307163.ogg
# Audio a segmentar-----> XC423979.ogg
# Audio a segmentar-----> XC672469.ogg
# Audio a segmentar-----> XC723730.ogg
# Audio a segmentar-----> XC325218.ogg
# Audio a segmentar-----> XC432573.ogg
# Audio a segmentar-----> XC390265.ogg
# Audio a segmentar-----> XC390250.ogg
# Audio a segmentar-----> XC837450.ogg
# Audio a segmentar-----> XC471959.ogg
# Audio a segmentar-----> XC310405.ogg
# Audio a segmentar-----> XC178397.ogg
# Audio a segmentar-----> XC471955.ogg
# Audio a segmentar-----> XC835051.ogg
# Audio a segmentar-----> XC840031.ogg
# Audio a segmentar-----> XC722419.ogg
# Audio a segmentar-----> XC334161.ogg
# Audio a segmentar-----> XC334159.ogg
# Audio a segmentar-----> XC732234.ogg
# Audio a segmentar-----> XC830658.ogg
# Audio a segmentar-----> XC318425.ogg
# Audio a segmentar-----> XC734722.ogg
# Audio a segmentar-----> XC423901.ogg
# Audio a segmentar-----> XC857584.ogg
# Audio a segmentar-----> XC442768.ogg
# Audio a segmentar-----> XC178391.ogg
# Audio a segmentar-----> XC243483.ogg
# Audio a segmentar-----> XC390257.ogg
# Audio a segmentar-----> XC749444.ogg
# Audio a segmentar-----> XC423981.ogg
# Audio a segmentar-----> XC734501.ogg
# Audio a segmentar-----> XC810556.ogg
# Audio a segmentar-----> XC463164.ogg
# Audio a segmentar-----> XC767569.ogg
# Audio a segmentar-----> XC310524.ogg
# Audio a segmentar-----> XC267777.ogg
# Audio a segmentar-----> XC282735.ogg
# Audio a segmentar-----> XC171582.ogg
# Audio a segmentar-----> XC827223.ogg
# Audio a segmentar-----> XC587231.ogg
# Audio a segmentar-----> XC857586.ogg
# Audio a segmentar-----> XC749418.ogg
# Audio a segmentar-----> XC330070.ogg
# Audio a segmentar-----> XC437891.ogg
# Audio a segmentar-----> XC423977.ogg
# Audio a segmentar-----> XC436739.ogg
# Audio a segmentar-----> XC293580.ogg
# Audio a segmentar-----> XC734720.ogg
# Audio a segmentar-----> XC627383.ogg
# Audio a segmentar-----> XC699937.ogg
# Audio a segmentar-----> XC331732.ogg
# Audio a segmentar-----> XC423976.ogg
# Audio a segmentar-----> XC701889.ogg
# Audio a segmentar-----> XC278426.ogg
# Audio a segmentar-----> XC587199.ogg
# Audio a segmentar-----> XC179801.ogg
# Audio a segmentar-----> XC188710.ogg
# Audio a segmentar-----> XC471957.ogg
# Audio a segmentar-----> XC638732.ogg
# Audio a segmentar-----> XC423903.ogg
# Audio a segmentar-----> XC213993.ogg
# Audio a segmentar-----> XC701888.ogg
# Audio a segmentar-----> XC789179.ogg
# Audio a segmentar-----> XC178396.ogg
# Audio a segmentar-----> XC701891.ogg
# Audio a segmentar-----> XC423911.ogg
# Audio a segmentar-----> XC390253.ogg
# Audio a segmentar-----> XC423980.ogg
# Audio a segmentar-----> XC430742.ogg
# Audio a segmentar-----> XC385379.ogg
# Audio a segmentar-----> XC502701.ogg
# Audio a segmentar-----> XC611239.ogg
# Audio a segmentar-----> XC445700.ogg
# Audio a segmentar-----> XC148621.ogg
# Audio a segmentar-----> XC794985.ogg
# Audio a segmentar-----> XC800516.ogg
# Audio a segmentar-----> XC330425.ogg
# Audio a segmentar-----> XC471774.ogg
# Audio a segmentar-----> XC469885.ogg
# Audio a segmentar-----> XC383377.ogg
# Audio a segmentar-----> XC432571.ogg
# Audio a segmentar-----> XC826359.ogg
# Audio a segmentar-----> XC390260.ogg
# Audio a segmentar-----> XC330426.ogg
# Audio a segmentar-----> XC370598.ogg
# Audio a segmentar-----> XC423983.ogg
# Audio a segmentar-----> XC736964.ogg
# Audio a segmentar-----> XC293058.ogg
# Audio a segmentar-----> XC145578.ogg
# Audio a segmentar-----> XC642599.ogg
# Audio a segmentar-----> XC585423.ogg
# Audio a segmentar-----> XC460972.ogg
# Audio a segmentar-----> XC637458.ogg
# Audio a segmentar-----> XC382091.ogg
# Audio a segmentar-----> XC423906.ogg
# Audio a segmentar-----> XC145577.ogg
# Audio a segmentar-----> XC178273.ogg
# Audio a segmentar-----> XC423909.ogg
# Audio a segmentar-----> XC775570.ogg
# Audio a segmentar-----> XC178398.ogg
# Audio a segmentar-----> XC777595.ogg
# Audio a segmentar-----> XC423972.ogg
# Audio a segmentar-----> XC735053.ogg
# Audio a segmentar-----> XC390263.ogg
# Audio a segmentar-----> XC144856.ogg
# Audio a segmentar-----> XC423904.ogg
# Audio a segmentar-----> XC464975.ogg
# Audio a segmentar-----> XC178394.ogg
# Audio a segmentar-----> XC433097.ogg
# Audio a segmentar-----> XC464439.ogg
# Audio a segmentar-----> XC423978.ogg
# Audio a segmentar-----> XC794724.ogg
# Audio a segmentar-----> XC800475.ogg
# Audio a segmentar-----> XC447361.ogg
# Audio a segmentar-----> XC825149.ogg
# Audio a segmentar-----> XC740067.ogg
# Audio a segmentar-----> XC278775.ogg
# Audio a segmentar-----> XC383401.ogg
# Audio a segmentar-----> XC829594.ogg
# Audio a segmentar-----> XC493838.ogg
# Audio a segmentar-----> XC193697.ogg
# Audio a segmentar-----> XC133800.ogg
# Audio a segmentar-----> XC423982.ogg
# Audio a segmentar-----> XC423984.ogg
# Audio a segmentar-----> XC267441.ogg
# Audio a segmentar-----> XC697566.ogg
# Audio a segmentar-----> XC835050.ogg
# Audio a segmentar-----> XC790247.ogg
# Audio a segmentar-----> XC390256.ogg
# Audio a segmentar-----> XC800474.ogg
# Audio a segmentar-----> XC835048.ogg
# Audio a segmentar-----> XC334160.ogg
# Audio a segmentar-----> XC423136.ogg
# Audio a segmentar-----> XC699938.ogg
# Audio a segmentar-----> XC467757.ogg
# Audio a segmentar-----> XC700182.ogg
# Audio a segmentar-----> XC176035.ogg
# Audio a segmentar-----> XC171583.ogg
# Audio a segmentar-----> XC721768.ogg
# Audio a segmentar-----> XC381917.ogg
# Audio a segmentar-----> XC399234.ogg
# Audio a segmentar-----> XC371367.ogg
# Audio a segmentar-----> XC175388.ogg
# Audio a segmentar-----> XC330427.ogg
# Audio a segmentar-----> XC832398.ogg
# Audio a segmentar-----> XC411312.ogg
# Audio a segmentar-----> XC828835.ogg
# Audio a segmentar-----> XC485355.ogg
# Audio a segmentar-----> XC857585.ogg
# Audio a segmentar-----> XC379520.ogg
# Audio a segmentar-----> XC267443.ogg
# Audio a segmentar-----> XC333855.ogg
# Audio a segmentar-----> XC836196.ogg
# Audio a segmentar-----> XC765899.ogg
# Audio a segmentar-----> XC718553.ogg
# Audio a segmentar-----> XC376957.ogg
# Audio a segmentar-----> XC494534.ogg
# Audio a segmentar-----> XC817406.ogg
# Audio a segmentar-----> XC185101.ogg
# Audio a segmentar-----> XC411002.ogg
# Audio a segmentar-----> XC185268.ogg
# Audio a segmentar-----> XC743063.ogg
# Audio a segmentar-----> XC812532.ogg
# Audio a segmentar-----> XC785268.ogg
# Audio a segmentar-----> XC494533.ogg
# Audio a segmentar-----> XC837287.ogg
# Audio a segmentar-----> XC718521.ogg
# Audio a segmentar-----> XC718550.ogg
# Audio a segmentar-----> XC316252.ogg
# Audio a segmentar-----> XC338267.ogg
# Audio a segmentar-----> XC817405.ogg
# Audio a segmentar-----> XC138233.ogg
# Audio a segmentar-----> XC371155.ogg
# Audio a segmentar-----> XC144531.ogg
# Audio a segmentar-----> XC634529.ogg
# Audio a segmentar-----> XC185273.ogg
# Audio a segmentar-----> XC812531.ogg
# Audio a segmentar-----> XC795873.ogg
# Audio a segmentar-----> XC836018.ogg
# Audio a segmentar-----> XC836805.ogg
# Audio a segmentar-----> XC807007.ogg
# Audio a segmentar-----> XC360814.ogg
# Audio a segmentar-----> XC778057.ogg
# Audio a segmentar-----> XC765286.ogg
# ...
# Audio a segmentar-----> XC648966.ogg
# Audio a segmentar-----> XC631991.ogg
# Audio a segmentar-----> XC308069.ogg
# Audio a segmentar-----> XC697952.ogg
# Audio a segmentar-----> XC214462.ogg
# Audio a segmentar-----> XC561426.ogg
# Audio a segmentar-----> XC271739.ogg
# Audio a segmentar-----> XC377581.ogg
# Audio a segmentar-----> XC611241.ogg
# Audio a segmentar-----> XC685943.ogg
# Audio a segmentar-----> XC374400.ogg
# Audio a segmentar-----> XC415625.ogg
# Audio a segmentar-----> XC334282.ogg
# Audio a segmentar-----> XC308876.ogg
# Audio a segmentar-----> XC325178.ogg
# Audio a segmentar-----> XC179797.ogg
# Audio a segmentar-----> XC823520.ogg
# Audio a segmentar-----> XC278195.ogg
# Audio a segmentar-----> XC644607.ogg
# Audio a segmentar-----> XC153911.ogg
# Audio a segmentar-----> XC631301.ogg
# Audio a segmentar-----> XC643901.ogg
# Audio a segmentar-----> XC267331.ogg
# Audio a segmentar-----> XC554671.ogg
# Audio a segmentar-----> XC813912.ogg
# Audio a segmentar-----> XC737257.ogg
# Audio a segmentar-----> XC237753.ogg
# Audio a segmentar-----> XC163320.ogg
# Audio a segmentar-----> XC368031.ogg
# Audio a segmentar-----> XC125950.ogg
# Audio a segmentar-----> XC278456.ogg
# Audio a segmentar-----> XC655332.ogg
# Audio a segmentar-----> XC815174.ogg
# Audio a segmentar-----> XC181656.ogg
# Audio a segmentar-----> XC469812.ogg
# Audio a segmentar-----> XC657763.ogg
# Audio a segmentar-----> XC570623.ogg
# Audio a segmentar-----> XC367977.ogg
# Audio a segmentar-----> XC375704.ogg
# Audio a segmentar-----> XC492192.ogg
# Audio a segmentar-----> XC814457.ogg
# Audio a segmentar-----> XC376682.ogg
# Audio a segmentar-----> XC627441.ogg
# Audio a segmentar-----> XC120517.ogg
# Audio a segmentar-----> XC408336.ogg
# Audio a segmentar-----> XC724610.ogg
# Audio a segmentar-----> XC560986.ogg
# Audio a segmentar-----> XC635854.ogg
# Audio a segmentar-----> XC853703.ogg
# Audio a segmentar-----> XC171538.ogg
# Audio a segmentar-----> XC815405.ogg
# Audio a segmentar-----> XC436342.ogg
# Audio a segmentar-----> XC482479.ogg
# Audio a segmentar-----> XC381947.ogg
# Audio a segmentar-----> XC555388.ogg
# Audio a segmentar-----> XC312068.ogg
# Audio a segmentar-----> XC318438.ogg
# Audio a segmentar-----> XC676410.ogg
# Audio a segmentar-----> XC641528.ogg
# Audio a segmentar-----> XC480798.ogg
# Audio a segmentar-----> XC667759.ogg
# Audio a segmentar-----> XC644371.ogg
# Audio a segmentar-----> XC416610.ogg
# Audio a segmentar-----> XC208453.ogg
# Audio a segmentar-----> XC417204.ogg
# Audio a segmentar-----> XC263714.ogg
# Audio a segmentar-----> XC799492.ogg
# Audio a segmentar-----> XC743432.ogg
# Audio a segmentar-----> XC451529.ogg
# Audio a segmentar-----> XC108366.ogg
# Audio a segmentar-----> XC473515.ogg
# Audio a segmentar-----> XC856149.ogg
# Audio a segmentar-----> XC157536.ogg
# Audio a segmentar-----> XC567265.ogg
# Audio a segmentar-----> XC184598.ogg
# Audio a segmentar-----> XC808508.ogg
# Audio a segmentar-----> XC306213.ogg
# Audio a segmentar-----> XC792465.ogg
# Audio a segmentar-----> XC184745.ogg
# Audio a segmentar-----> XC387611.ogg
# Audio a segmentar-----> XC554669.ogg
# Audio a segmentar-----> XC179276.ogg
# Audio a segmentar-----> XC398490.ogg
# Audio a segmentar-----> XC449201.ogg
# Audio a segmentar-----> XC626971.ogg
# Audio a segmentar-----> XC184744.ogg
# Audio a segmentar-----> XC714279.ogg
# Audio a segmentar-----> XC689716.ogg
# Audio a segmentar-----> XC544855.ogg
# Audio a segmentar-----> XC838414.ogg
# Audio a segmentar-----> XC316863.ogg
# Audio a segmentar-----> XC374775.ogg
# Audio a segmentar-----> XC308875.ogg
# Audio a segmentar-----> XC365028.ogg
# Audio a segmentar-----> XC337010.ogg
# Audio a segmentar-----> XC306215.ogg
# Audio a segmentar-----> XC457439.ogg
# Audio a segmentar-----> XC570613.ogg
# Audio a segmentar-----> XC807511.ogg
# Audio a segmentar-----> XC306289.ogg
# Audio a segmentar-----> XC399125.ogg
# Audio a segmentar-----> XC768924.ogg
# Audio a segmentar-----> XC790568.ogg
# Audio a segmentar-----> XC396426.ogg
# Audio a segmentar-----> XC551357.ogg
# Audio a segmentar-----> XC265784.ogg
# Audio a segmentar-----> XC736463.ogg
# Audio a segmentar-----> XC793074.ogg
# Audio a segmentar-----> XC722560.ogg
# Audio a segmentar-----> XC428895.ogg
# Audio a segmentar-----> XC728033.ogg
# Audio a segmentar-----> XC472506.ogg
# Audio a segmentar-----> XC787620.ogg
# Audio a segmentar-----> XC631581.ogg
# Audio a segmentar-----> XC560383.ogg
# Audio a segmentar-----> XC788394.ogg
# Audio a segmentar-----> XC162589.ogg
# Audio a segmentar-----> XC646546.ogg
# Audio a segmentar-----> XC659748.ogg
# Audio a segmentar-----> XC684937.ogg
# Audio a segmentar-----> XC627443.ogg
# Audio a segmentar-----> XC627442.ogg
# Audio a segmentar-----> XC666153.ogg
# Audio a segmentar-----> XC654368.ogg
# Audio a segmentar-----> XC376646.ogg
# Audio a segmentar-----> XC170884.ogg
# Audio a segmentar-----> XC768913.ogg
# Audio a segmentar-----> XC798813.ogg
# Audio a segmentar-----> XC240325.ogg
# Audio a segmentar-----> XC741847.ogg
# Audio a segmentar-----> XC170885.ogg
# Audio a segmentar-----> XC707604.ogg
# Audio a segmentar-----> XC312070.ogg
# Audio a segmentar-----> XC137661.ogg
# Audio a segmentar-----> XC240517.ogg
# Audio a segmentar-----> XC431407.ogg
# Audio a segmentar-----> XC692719.ogg
# Audio a segmentar-----> XC317080.ogg
# Audio a segmentar-----> XC306214.ogg
# Audio a segmentar-----> XC551446.ogg
# Audio a segmentar-----> XC410050.ogg
# Audio a segmentar-----> XC246029.ogg
# Audio a segmentar-----> XC807306.ogg
# Audio a segmentar-----> XC459931.ogg
# Audio a segmentar-----> XC382177.ogg
# Audio a segmentar-----> XC688478.ogg
# Audio a segmentar-----> XC809234.ogg
# Audio a segmentar-----> XC365530.ogg
# Audio a segmentar-----> XC789272.ogg
# Audio a segmentar-----> XC370455.ogg
# Audio a segmentar-----> XC844248.ogg
# Audio a segmentar-----> XC827681.ogg
# Audio a segmentar-----> XC543787.ogg
# Audio a segmentar-----> XC802070.ogg
# Audio a segmentar-----> XC787093.ogg
# Audio a segmentar-----> XC202567.ogg
# Audio a segmentar-----> XC472504.ogg
# Audio a segmentar-----> XC597972.ogg
# Audio a segmentar-----> XC799485.ogg
# Audio a segmentar-----> XC722698.ogg
# Audio a segmentar-----> XC815170.ogg
# Audio a segmentar-----> XC728537.ogg
# Audio a segmentar-----> XC804457.ogg
# Audio a segmentar-----> XC551275.ogg
# Audio a segmentar-----> XC166835.ogg
# Audio a segmentar-----> XC413324.ogg
# Audio a segmentar-----> XC585632.ogg
# Audio a segmentar-----> XC718549.ogg
# Audio a segmentar-----> XC557916.ogg
# Audio a segmentar-----> XC277454.ogg
# Audio a segmentar-----> XC173495.ogg
# Audio a segmentar-----> XC281072.ogg
# Audio a segmentar-----> XC279736.ogg
# Audio a segmentar-----> XC844515.ogg
# Audio a segmentar-----> XC803800.ogg
# Audio a segmentar-----> XC365529.ogg
# Audio a segmentar-----> XC795276.ogg
# Audio a segmentar-----> XC685941.ogg
# Audio a segmentar-----> XC808749.ogg
# Audio a segmentar-----> XC549372.ogg
# Audio a segmentar-----> XC570576.ogg
# Audio a segmentar-----> XC374453.ogg
# Audio a segmentar-----> XC134047.ogg
# Audio a segmentar-----> XC291958.ogg
# Audio a segmentar-----> XC176956.ogg
# Audio a segmentar-----> XC491981.ogg
# Audio a segmentar-----> XC858396.ogg
# Audio a segmentar-----> XC655333.ogg
# Audio a segmentar-----> XC761313.ogg
# Audio a segmentar-----> XC652235.ogg
# Audio a segmentar-----> XC633570.ogg
# Audio a segmentar-----> XC179516.ogg
# Audio a segmentar-----> XC343651.ogg
# Audio a segmentar-----> XC312065.ogg
# Audio a segmentar-----> XC480810.ogg
# Audio a segmentar-----> XC370157.ogg
# Audio a segmentar-----> XC710302.ogg
# Audio a segmentar-----> XC789694.ogg
# Audio a segmentar-----> XC701405.ogg
# Audio a segmentar-----> XC410756.ogg
# Audio a segmentar-----> XC279094.ogg
# Audio a segmentar-----> XC625440.ogg
# Audio a segmentar-----> XC810151.ogg
# Audio a segmentar-----> XC298305.ogg
# Audio a segmentar-----> XC349675.ogg
# Audio a segmentar-----> XC789270.ogg
# Audio a segmentar-----> XC358155.ogg
# Audio a segmentar-----> XC790527.ogg
# Audio a segmentar-----> XC611595.ogg
# Audio a segmentar-----> XC437486.ogg
# Audio a segmentar-----> XC162588.ogg
# Audio a segmentar-----> XC281064.ogg
# Audio a segmentar-----> XC802096.ogg
# Audio a segmentar-----> XC856141.ogg
# Audio a segmentar-----> XC650177.ogg
# Audio a segmentar-----> XC521891.ogg
# Audio a segmentar-----> XC487072.ogg
# Audio a segmentar-----> XC697586.ogg
# Audio a segmentar-----> XC598504.ogg
# Audio a segmentar-----> XC560960.ogg
# Audio a segmentar-----> XC504434.ogg
# Audio a segmentar-----> XC325173.ogg
# Audio a segmentar-----> XC781667.ogg
# Audio a segmentar-----> XC555386.ogg
# Audio a segmentar-----> XC367997.ogg
# Audio a segmentar-----> XC820519.ogg
# Audio a segmentar-----> XC145090.ogg
# Audio a segmentar-----> XC789274.ogg
# Audio a segmentar-----> XC469245.ogg
# Audio a segmentar-----> XC617644.ogg
# Audio a segmentar-----> XC647566.ogg
# Audio a segmentar-----> XC401686.ogg
# Audio a segmentar-----> XC240516.ogg
# Audio a segmentar-----> XC293484.ogg
# Audio a segmentar-----> XC410755.ogg
# Audio a segmentar-----> XC399124.ogg
# Audio a segmentar-----> XC423759.ogg
# Audio a segmentar-----> XC844526.ogg
# Audio a segmentar-----> XC516341.ogg
# Audio a segmentar-----> XC243481.ogg
# Audio a segmentar-----> XC796675.ogg
# Audio a segmentar-----> XC807513.ogg
# Audio a segmentar-----> XC478800.ogg
# Audio a segmentar-----> XC702279.ogg
# Audio a segmentar-----> XC376351.ogg
# Audio a segmentar-----> XC752875.ogg
# Audio a segmentar-----> XC804620.ogg
# Audio a segmentar-----> XC548298.ogg
# Audio a segmentar-----> XC800789.ogg
# Audio a segmentar-----> XC560349.ogg
# Audio a segmentar-----> XC376683.ogg
# Audio a segmentar-----> XC710304.ogg
# Audio a segmentar-----> XC520009.ogg
# Audio a segmentar-----> XC424024.ogg
# Audio a segmentar-----> XC617643.ogg
# Audio a segmentar-----> XC467855.ogg
# Audio a segmentar-----> XC551277.ogg
# Audio a segmentar-----> XC402638.ogg
# Audio a segmentar-----> XC278154.ogg
# Audio a segmentar-----> XC371170.ogg
# Audio a segmentar-----> XC607916.ogg
# Audio a segmentar-----> XC577029.ogg
# Audio a segmentar-----> XC504497.ogg
# Audio a segmentar-----> XC202569.ogg
# Audio a segmentar-----> XC631304.ogg
# Audio a segmentar-----> XC447568.ogg
# Audio a segmentar-----> XC181658.ogg
# Audio a segmentar-----> XC842273.ogg
# Audio a segmentar-----> XC574180.ogg
# Audio a segmentar-----> XC461841.ogg
# Audio a segmentar-----> XC416039.ogg
# Audio a segmentar-----> XC368546.ogg
# Audio a segmentar-----> XC798811.ogg
# Audio a segmentar-----> XC798803.ogg
# Audio a segmentar-----> XC403576.ogg
# Audio a segmentar-----> XC560366.ogg
# Audio a segmentar-----> XC264882.ogg
# Audio a segmentar-----> XC310261.ogg
# Audio a segmentar-----> XC467861.ogg
# Audio a segmentar-----> XC789267.ogg
# Audio a segmentar-----> XC457301.ogg
# Audio a segmentar-----> XC677453.ogg
# Audio a segmentar-----> XC856086.ogg
# Audio a segmentar-----> XC371174.ogg
# Audio a segmentar-----> XC716240.ogg
# Audio a segmentar-----> XC157534.ogg
# Audio a segmentar-----> XC240326.ogg
# Audio a segmentar-----> XC480280.ogg
# Audio a segmentar-----> XC793076.ogg
# Audio a segmentar-----> XC800831.ogg
# Audio a segmentar-----> XC477326.ogg
# Audio a segmentar-----> XC655319.ogg
# Audio a segmentar-----> XC639406.ogg
# Audio a segmentar-----> XC182499.ogg
# Audio a segmentar-----> XC312069.ogg
# Audio a segmentar-----> XC264859.ogg
# Audio a segmentar-----> XC303733.ogg
# Audio a segmentar-----> XC522078.ogg
# Audio a segmentar-----> XC551273.ogg
# Audio a segmentar-----> XC308874.ogg
# Audio a segmentar-----> XC657760.ogg
# Audio a segmentar-----> XC363903.ogg
# Audio a segmentar-----> XC357489.ogg
# Audio a segmentar-----> XC179798.ogg
# Audio a segmentar-----> XC729989.ogg
# Audio a segmentar-----> XC308878.ogg
# Audio a segmentar-----> XC647839.ogg
# Audio a segmentar-----> XC417570.ogg
# Audio a segmentar-----> XC827773.ogg
# Audio a segmentar-----> XC560376.ogg
# Audio a segmentar-----> XC187389.ogg
# Audio a segmentar-----> XC560357.ogg
# Audio a segmentar-----> XC560353.ogg
# Audio a segmentar-----> XC666638.ogg
# Audio a segmentar-----> XC476606.ogg
# Audio a segmentar-----> XC195496.ogg
# Audio a segmentar-----> XC73265.ogg
# Audio a segmentar-----> XC362810.ogg
# Audio a segmentar-----> XC756584.ogg
# Audio a segmentar-----> XC740171.ogg
# Audio a segmentar-----> XC302002.ogg
# Audio a segmentar-----> XC124922.ogg
# Audio a segmentar-----> XC597948.ogg
# Audio a segmentar-----> XC571984.ogg
# Audio a segmentar-----> XC41378.ogg
# Audio a segmentar-----> XC641519.ogg
# Audio a segmentar-----> XC541991.ogg
# Audio a segmentar-----> XC665709.ogg
# Audio a segmentar-----> XC555521.ogg
# Audio a segmentar-----> XC382148.ogg
# Audio a segmentar-----> XC858822.ogg
# Audio a segmentar-----> XC207257.ogg
# Audio a segmentar-----> XC747121.ogg
# Audio a segmentar-----> XC683306.ogg
# Audio a segmentar-----> XC550179.ogg
# Audio a segmentar-----> XC447553.ogg
# Audio a segmentar-----> XC736745.ogg
# Audio a segmentar-----> XC184999.ogg
# Audio a segmentar-----> XC684740.ogg
# Audio a segmentar-----> XC447554.ogg
# Audio a segmentar-----> XC511236.ogg
# Audio a segmentar-----> XC572663.ogg
# Audio a segmentar-----> XC499667.ogg
# Audio a segmentar-----> XC432448.ogg
# Audio a segmentar-----> XC802092.ogg
# Audio a segmentar-----> XC282569.ogg
# Audio a segmentar-----> XC722783.ogg
# Audio a segmentar-----> XC423740.ogg
# Audio a segmentar-----> XC576908.ogg
# Audio a segmentar-----> XC295449.ogg
# Audio a segmentar-----> XC802192.ogg
# Audio a segmentar-----> XC786977.ogg
# Audio a segmentar-----> XC786297.ogg
# Audio a segmentar-----> XC362824.ogg
# Audio a segmentar-----> XC741504.ogg
# Audio a segmentar-----> XC613961.ogg
# Audio a segmentar-----> XC276855.ogg
# Audio a segmentar-----> XC641522.ogg
# Audio a segmentar-----> XC326853.ogg
# Audio a segmentar-----> XC858987.ogg
# Audio a segmentar-----> XC823527.ogg
# Audio a segmentar-----> XC42624.ogg
# Audio a segmentar-----> XC858986.ogg
# Audio a segmentar-----> XC385863.ogg
# Audio a segmentar-----> XC608343.ogg
# Audio a segmentar-----> XC572628.ogg
# Audio a segmentar-----> XC189334.ogg
# Audio a segmentar-----> XC467427.ogg
# Audio a segmentar-----> XC488788.ogg
# Audio a segmentar-----> XC792263.ogg
# Audio a segmentar-----> XC768922.ogg
# Audio a segmentar-----> XC558710.ogg
# Audio a segmentar-----> XC430251.ogg
# Audio a segmentar-----> XC768921.ogg
# Audio a segmentar-----> XC467426.ogg
# Audio a segmentar-----> XC487517.ogg
# Audio a segmentar-----> XC778992.ogg
# Audio a segmentar-----> XC381169.ogg
# Audio a segmentar-----> XC302001.ogg
# Audio a segmentar-----> XC239353.ogg
# Audio a segmentar-----> XC362825.ogg
# Audio a segmentar-----> XC406647.ogg
# Audio a segmentar-----> XC641524.ogg
# Audio a segmentar-----> XC476069.ogg
# Audio a segmentar-----> XC362110.ogg
# Audio a segmentar-----> XC385864.ogg
# Audio a segmentar-----> XC709688.ogg
# Audio a segmentar-----> XC665436.ogg
# Audio a segmentar-----> XC153013.ogg
# Audio a segmentar-----> XC316823.ogg
# Audio a segmentar-----> XC558852.ogg
# Audio a segmentar-----> XC194941.ogg
# Audio a segmentar-----> XC634264.ogg
# Audio a segmentar-----> XC541994.ogg
# Audio a segmentar-----> XC584165.ogg
# Audio a segmentar-----> XC302000.ogg
# Audio a segmentar-----> XC823428.ogg
# Audio a segmentar-----> XC818177.ogg
# Audio a segmentar-----> XC620791.ogg
# Audio a segmentar-----> XC709698.ogg
# Audio a segmentar-----> XC802191.ogg
# Audio a segmentar-----> XC363614.ogg
# Audio a segmentar-----> XC641510.ogg
# Audio a segmentar-----> XC430258.ogg
# Audio a segmentar-----> XC453363.ogg
# Audio a segmentar-----> XC331899.ogg
# Audio a segmentar-----> XC487793.ogg
# Audio a segmentar-----> XC173239.ogg
# Audio a segmentar-----> XC723907.ogg
# Audio a segmentar-----> XC802726.ogg
# Audio a segmentar-----> XC775453.ogg
# Audio a segmentar-----> XC723993.ogg
# Audio a segmentar-----> XC775448.ogg
# Audio a segmentar-----> XC260257.ogg
# Audio a segmentar-----> XC718047.ogg
# Audio a segmentar-----> XC468290.ogg
# Audio a segmentar-----> XC74151.ogg
# Audio a segmentar-----> XC447853.ogg
# Audio a segmentar-----> XC576905.ogg
# Audio a segmentar-----> XC334898.ogg
# Audio a segmentar-----> XC643897.ogg
# Audio a segmentar-----> XC207637.ogg
# Audio a segmentar-----> XC383770.ogg
# Audio a segmentar-----> XC319053.ogg
# Audio a segmentar-----> XC548375.ogg
# Audio a segmentar-----> XC419415.ogg
# Audio a segmentar-----> XC326854.ogg
# Audio a segmentar-----> XC547181.ogg
# Audio a segmentar-----> XC858985.ogg
# Minima energia dos min filtrado 0.02058342876746825
# Dados Filtrados: 6211
# Mean: 0.02058342876746825
